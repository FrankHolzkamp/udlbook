# %% [markdown]
# <a href="https://colab.research.google.com/github/FrankHolzkamp/udlbook/blob/main/learn%20fundamentals%20with%20numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Imports math library
import numpy as np
# Imports plotting library
import matplotlib.pyplot as plt
# Import math Library
import math
